# %%
import pandas as pd
cols=['X','Y']
lr=pd.read_csv('Ds3.csv')
lr
# Out:
#        X    Y
# 0    6.2   29
# 1    9.5   44
# 2   10.5   36
# 3    7.7   37
# 4    8.6   53
# 5   34.1   68
# 6   11.0   75
# 7    6.9   18
# 8    7.3   31
# 9   15.1   25
# 10  29.1   34
# 11   2.2   14
# 12   5.7   11
# 13   2.0   11
# 14   2.5   22
# 15   4.0   16
# 16   5.4   27
# 17   2.2    9
# 18   7.2   29
# 19  15.1   30
# 20  16.5   40
# 21  18.4   32
# 22  36.2   41
# 23  39.7  147
# 24  18.5   22
# 25  23.3   29
# 26  12.2   46
# 27   5.6   23
# 28  21.8    4
# 29  21.6   31
# 30   9.0   39
# 31   3.6   15
# 32   5.0   32
# 33  28.6   27
# 34  17.4   32
# 35  11.3   34
# 36   3.4   17
# 37  11.9   46
# 38  10.5   42
# 39  10.7   43
# 40  10.8   34
# 41   4.8   19

# %%
mex=lr['X'].mean()
mey=lr['Y'].mean()
x=lr['X']
xsq=pow(x,2)
mexsq=xsq.mean()
sqmex=pow(mex,2)
xy=lr['X']*lr['Y']
mexy=xy.mean()

# %%
a1=(mexy-(mex*mey))/(mexsq-sqmex)
print(a1)
a0=mey-a1*mex
print(a0)
# Out:
# 1.3134560049239148
# 16.995157232739547

# %%
ycap=a0+a1*lr['X']
lr['ycap']=ycap
lr
# Out:
#        X    Y       ycap
# 0    6.2   29  25.138584
# 1    9.5   44  29.472989
# 2   10.5   36  30.786445
# 3    7.7   37  27.108768
# 4    8.6   53  28.290879
# 5   34.1   68  61.784007
# 6   11.0   75  31.443173
# 7    6.9   18  26.058004
# 8    7.3   31  26.583386
# 9   15.1   25  36.828343
# 10  29.1   34  55.216727
# 11   2.2   14  19.884760
# 12   5.7   11  24.481856
# 13   2.0   11  19.622069
# 14   2.5   22  20.278797
# 15   4.0   16  22.248981
# 16   5.4   27  24.087820
# 17   2.2    9  19.884760
# 18   7.2   29  26.452040
# 19  15.1   30  36.828343
# 20  16.5   40  38.667181
# 21  18.4   32  41.162748
# 22  36.2   41  64.542265
# 23  39.7  147  69.139361
# 24  18.5   22  41.294093
# 25  23.3   29  47.598682
# 26  12.2   46  33.019320
# 27   5.6   23  24.350511
# 28  21.8    4  45.628498
# 29  21.6   31  45.365807
# 30   9.0   39  28.816261
# 31   3.6   15  21.723599
# 32   5.0   32  23.562437
# 33  28.6   27  54.559999
# 34  17.4   32  39.849292
# 35  11.3   34  31.837210
# ...

# %%
a=lr['ycap']-mey
b=lr['Y']-mey
a2=a*a
b2=b*b
a2_sum=a2.sum()
b2_sum=b2.sum()
r2=a2_sum/b2_sum
r2
# Out:
# 0.3037346895973593

# %%
import matplotlib.pyplot as mt
mt.scatter(lr['X'],lr['Y'])
mt.plot(lr['X'],lr['ycap'],color='green')
mt.show()
