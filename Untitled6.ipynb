# %%
import pandas as pd
import math

import numpy as np

df=pd.read_csv("DT_DS.csv")
df
# Out:
#    sno cgpa interact     pk        cs   jo
# 0    1  >=9      yes  vgood      good  yes
# 1    2  >=8       no   good  moderate  yes
# 2    3  >=9       no    avg      poor   no
# 3    4   <8       no    avg      good   no
# 4    5  >=8      yes   good  moderate  yes
# 5    6  >=9      yes   good  moderate  yes
# 6    7   <8      yes   good      poor   no
# 7    8  >=9       no  vgood      good  yes
# 8    9  >=8      yes   good      good  yes
# 9   10  >=8      yes    avg      good  yes

# %%
def entropy_(df):
    entrop=0
    yes=df[df['jo']=='yes'].value_counts().sum()
    no=df[df['jo']=='no'].value_counts().sum()
    entrop=-(yes/len(df))*math.log2(yes/len(df))-(no/len(df))*math.log2(no/len(df))
    print("Entropy of TV",entrop)
    return entropy_

# %%
def entropy_info1(df,attribute,entropy1):
    entropy_info=0
    values=df[attribute].value_counts()
    print(f'{values}\n')
    for value in values.index:
        yes=df[df['jo']=='yes'][df[attribute]==value].value_counts().sum()
        no=df[df['jo']=='no'][df[attribute]==value].value_counts().sum()
        print(f'For {attribute} {value}, Job offer : Yes = {yes} and No = {no}')
        if yes==0 or no==0:
            entropy_info+=0
        elif yes==no:
            entropy_info+=((yes+no)/len(df))*1
        else:
            entropy_info+=((yes+no)/len(df))*(-(yes/(yes+no)*math.log2(yes/(yes+no)))-(no/(yes+no)*math.log2(no/(yes+no))))
    gain=entropy1-entropy_info
    print(f'\nEntropy Info({attribute},job offer) = {entropy_info}')
    print(f'Gain ({attribute}) = {gain}\n')
    return gain

# %%
def bestattribute(df):
    entropy = entropy_(df)
    attributes=['cgpa','interact','pk','cs']
    root=''
    maxgain=0
    for attribute in attributes:
        gain = entropy_info1(df,attribute,entropy)
        if gain>maxgain:
            maxgain=gain
            root=attribute
    print(f'Since Gain of attribute {root} is greater, Root attribute is {root}')
    return root

# %%
def splitdata(df,attribute):
    return df[attribute].unique()

# %%
def buildtree(i,df,tree=None):
    print(f'\nIteration {i+1}\n')
    attribute=bestattribute(df)
    if tree is None:
        tree={}
        tree[attribute]={}
    for value in splitdata(df,attribute):
        subtable=df[df[attribute]==value].reset_index(drop=True)
        clvalue,counts=np.unique(subtable['jo'],return_counts=True)
        if len(counts)==1:
            tree[attribute][value]=clvalue[0]
        else:
            tree[attribute][value]=buildtree(i+1,subtable)
    return tree

# %%
buildtree(0,df)
# Out:
# Iteration 1
#
# Entropy of TV 0.8812908992306927
# >=9    4
# >=8    4
# <8     2
# Name: cgpa, dtype: int64
#
# For cgpa >=9, Job offer : Yes = 3 and No = 1
# For cgpa >=8, Job offer : Yes = 4 and No = 0
# For cgpa <8, Job offer : Yes = 0 and No = 2
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   yes=df[df['jo']=='yes'][df[attribute]==value].value_counts().sum()
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   no=df[df['jo']=='no'][df[attribute]==value].value_counts().sum()
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   yes=df[df['jo']=='yes'][df[attribute]==value].value_counts().sum()
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   no=df[df['jo']=='no'][df[attribute]==value].value_counts().sum()
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   yes=df[df['jo']=='yes'][df[attribute]==value].value_counts().sum()
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1548\579516620.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   no=df[df['jo']=='no'][df[attribute]==value].value_counts().sum()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1548\1758485208.py in <module>
# ----> 1 buildtree(0,df)
#
# ~\AppData\Local\Temp\ipykernel_1548\578481652.py in buildtree(i, df, tree)
#       1 def buildtree(i,df,tree=None):
#       2     print(f'\nIteration {i+1}\n')
# ----> 3     attribute=bestattribute(df)
#       4     if tree is None:
#       5         tree={}
#
# ~\AppData\Local\Temp\ipykernel_1548\2015637853.py in bestattribute(df)
#       5     maxgain=0
#       6     for attribute in attributes:
# ----> 7         gain = entropy_info1(df,attribute,entropy)
#       8         if gain>maxgain:
#       9             maxgain=gain
#
# ~\AppData\Local\Temp\ipykernel_1548\579516620.py in entropy_info1(df, attribute, entropy1)
#      13         else:
#      14             entropy_info+=((yes+no)/len(df))*(-(yes/(yes+no)*math.log2(yes/(yes+no)))-(no/(yes+no)*math.log2(no/(yes+no))))
# ---> 15     gain=entropy1-entropy_info
#      16     print(f'\nEntropy Info({attribute},job offer) = {entropy_info}')
#      17     print(f'Gain ({attribute}) = {gain}\n')
#
# TypeError: unsupported operand type(s) for -: 'function' and 'float'
