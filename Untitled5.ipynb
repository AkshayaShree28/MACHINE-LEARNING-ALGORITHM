# %%
import pandas as pd
data=pd.read_csv('KNNData.csv')
data
testinstance
# Out:
#    Sno  Height  Weight        Class
# 0    1     167      51  Underweight
# 1    2     182      62       Normal
# 2    3     176      69       Normal
# 3    4     173      64       Normal
# 4    5     172      65       Normal
# 5    6     174      56  Underweight
# 6    7     169      58       Normal
# 7    8     173      57       Normal
# 8    9     170      55       Normal
# 9   10     176      59      Normal

# %%
def distance()
